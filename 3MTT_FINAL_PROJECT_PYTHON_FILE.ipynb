# %% [markdown]
# # 3MTT FINAL PROJECT
# ### TOPIC:
# ## ROAD ACCIDENT
# ### BY:
# ## YAKUBU ZAHARADEEN
# ### FELLOW ID:
# ## FE/23/74757623

# %% [markdown]
# # DATA CLEANING AND PROCESSING OF ROAD ACCIDENT DATASET

# %% [markdown]
# ## 1. IMPORTING LIBERARIES

# %%
# importing liberary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %% [markdown]
# ## 2. IMPORTING DATASET FROM EXCEL TO PYTHON

# %%
# importing dataset
df = pd.read_excel(r"C:\Users\Dell\Desktop\prctce1.xlsx")

# %% [markdown]
# ## 3. DISPLAYING IMPORTED DATASET

# %%
# displaying first five rows of the dataset
df.head()
# Out:
#   Accident_Index Accident Date Month  Year Day_of_Week  \
# 0  200901BS70001    2021-01-01   Jan  2021  Thursday..
# 1  200901BS70002    2021-01-05   Jan  2021      Monday
# 2  200901BS70003    2021-01-04   Jan  2021      Sunday
# 3  200901BS70004    2021-01-05   Jan  2021      Monday
# 4  200901BS70005    2021-01-06   Jan  2021     Tuesday
#
#            Junction_Control          Junction_Detail Accident_Severity  \
# 0  Give way or uncontrolled  T or staggered junction           Serious
# 1  Give way or uncontrolled               Crossroads           Serious
# 2  Give way or uncontrolled  T or staggered junction            Slight
# 3       Auto traffic signal  T or staggered junction           Serious
# 4       Auto traffic signal               Crossroads           Serious
#
#     Latitude       Light_Conditions  ... Number_of_Casualties  \
# 0  51.512273               Daylight  ...                    1
# 1  51.514399               Daylight  ...                   11
# ...

# %%
# displaying last five rows of the dataset
df.tail()
# Out:
#        Accident_Index Accident Date Month  Year Day_of_Week  \
# 307969  201091NM01881    2022-02-21   Feb  2022      Sunday
# 307970  201091NM01935    2022-02-23   Feb  2022     Tuesday
# 307971  201091NM01964    2022-02-23   Feb  2022     Tuesday
# 307972  201091NM02142    2022-02-28   Feb  2022      Sunday
# 307973  201091NM02142    2022-02-28   Feb  2022      Sunday
#
#                     Junction_Control                      Junction_Detail  \
# 307969  Data missing or out of range  Not at junction or within 20 metres
# 307970      Give way or uncontrolled              T or staggered junction
# 307971      Give way or uncontrolled              T or staggered junction
# 307972      Give way or uncontrolled              T or staggered junction
# 307973      Give way or uncontrolled              T or staggered junction
#
#        Accident_Severity   Latitude        Light_Conditions  ...  \
# 307969            Slight  57.232273  Darkness - no lighting  ...
# ...

# %% [markdown]
# ## 4. DISPLAYING BASIC DATASET INFORMATION AND DESCRIPTION

# %%
# displaying dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307974 entries, 0 to 307973
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident_Index              307974 non-null  object
#  1   Accident Date               307974 non-null  datetime64[ns]
#  2   Month                       307974 non-null  object
#  3   Year                        307974 non-null  int64
#  4   Day_of_Week                 307974 non-null  object
#  5   Junction_Control            307974 non-null  object
#  6   Junction_Detail             307974 non-null  object
#  7   Accident_Severity           307974 non-null  object
#  8   Latitude                    307974 non-null  float64
#  9   Light_Conditions            307974 non-null  object
#  10  Local_Authority_(District)  307974 non-null  object
#  11  Carriageway_Hazards         5425 non-null    object
# ...

# %%
# displaying dataset file description
df.describe()
# Out:
#                        Accident Date           Year       Latitude  \
# count                         307974  307974.000000  307974.000000
# mean   2021-12-23 22:19:58.340119552    2021.468936      52.487021
# min              2021-01-01 00:00:00    2021.000000      49.914488
# 25%              2021-06-28 00:00:00    2021.000000      51.485248
# 50%              2021-12-08 00:00:00    2021.000000      52.225952
# 75%              2022-06-25 00:00:00    2022.000000      53.415517
# max              2022-12-31 00:00:00    2022.000000      60.598055
# std                              NaN       0.499035       1.339040
#
#            Longitude  Number_of_Casualties  Number_of_Vehicles    Speed_limit
# count  307974.000000         307974.000000       307974.000000  307974.000000
# mean       -1.368892              1.356881            1.829060      38.866106
# min        -7.516225              1.000000            1.000000      10.000000
# ...

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ## 5. REMOVING DUPLICATES

# %%
# removing duplicates from the whole dataset
df = df.drop_duplicates()

# %%
# displaying parts where duplicates where removed
df.tail()
# Out:
#        Accident_Index Accident Date Month  Year Day_of_Week  \
# 307968  201091NM01760    2022-02-18   Feb  2022    Thursday
# 307969  201091NM01881    2022-02-21   Feb  2022      Sunday
# 307970  201091NM01935    2022-02-23   Feb  2022     Tuesday
# 307971  201091NM01964    2022-02-23   Feb  2022     Tuesday
# 307972  201091NM02142    2022-02-28   Feb  2022      Sunday
#
#                     Junction_Control                      Junction_Detail  \
# 307968  Data missing or out of range  Not at junction or within 20 metres
# 307969  Data missing or out of range  Not at junction or within 20 metres
# 307970      Give way or uncontrolled              T or staggered junction
# 307971      Give way or uncontrolled              T or staggered junction
# 307972      Give way or uncontrolled              T or staggered junction
#
#        Accident_Severity   Latitude        Light_Conditions  ...  \
# 307968            Slight  57.374005                Daylight  ...
# ...

# %% [markdown]
# ### NOTE:- Looking at output[4] from the code cell you will discover that duplicate exist in two last row of the dataset and need to be removed. looking at the output[8] from code cell Duplicate was removed from the last row of the dataset hence my reason for displaying the last five rows of the dataset

# %% [markdown]
# ## 6. DROPPING UNWANTED COLUMNS

# %%
# removing columns
df = df.drop(columns = "Latitude")

# %%
# displaying head to confirm removed column
df.head()
# Out:
#   Accident_Index Accident Date Month  Year Day_of_Week  \
# 0  200901BS70001    2021-01-01   Jan  2021  Thursday..
# 1  200901BS70002    2021-01-05   Jan  2021      Monday
# 2  200901BS70003    2021-01-04   Jan  2021      Sunday
# 3  200901BS70004    2021-01-05   Jan  2021      Monday
# 4  200901BS70005    2021-01-06   Jan  2021     Tuesday
#
#            Junction_Control          Junction_Detail Accident_Severity  \
# 0  Give way or uncontrolled  T or staggered junction           Serious
# 1  Give way or uncontrolled               Crossroads           Serious
# 2  Give way or uncontrolled  T or staggered junction            Slight
# 3       Auto traffic signal  T or staggered junction           Serious
# 4       Auto traffic signal               Crossroads           Serious
#
#         Light_Conditions Local_Authority_(District)  ... Number_of_Casualties  \
# 0               Daylight     Kensington and Chelsea  ...                    1
# ...

# %% [markdown]
# ## 7. REMOVING UNWANTED CHARACTERS IN COLUMNS

# %%
# removing unwanted characters from "Day_of_Week" column
df["Day_of_Week"] = df["Day_of_Week"].str.strip("123._/-")

# %%
# displaying dataset to view removed characters
df.head(15)
# Out:
#    Accident_Index Accident Date Month  Year Day_of_Week  \
# 0   200901BS70001    2021-01-01   Jan  2021    Thursday
# 1   200901BS70002    2021-01-05   Jan  2021      Monday
# 2   200901BS70003    2021-01-04   Jan  2021      Sunday
# 3   200901BS70004    2021-01-05   Jan  2021      Monday
# 4   200901BS70005    2021-01-06   Jan  2021     Tuesday
# 5   200901BS70006    2021-01-01   Jan  2021    Thursday
# 6   200901BS70007    2021-01-08   Jan  2021    Thursday
# 7   200901BS70008    2021-01-02   Jan  2021      Friday
# 8   200901BS70009    2021-01-07   Jan  2021   Wednesday
# 9   200901BS70010    2021-01-10   Jan  2021    Saturday
# 10  200901BS70011    2021-01-07   Jan  2021   Wednesday
# 11  200901BS70012    2021-01-16   Jan  2021      Friday
# 12  200901BS70015    2021-01-12   Jan  2021      Monday
# 13  200901BS70016    2021-01-09   Jan  2021      Friday
# 14  200901BS70017    2021-01-17   Jan  2021    Saturday
#
# ...

# %% [markdown]
# # DATA PROCESSING

# %% [markdown]
# ## 8. CREATING A PIVOT TABLE

# %%
# creating pivot table
pivot_table_df = pd.pivot_table(df, values = ["Month", "Number_of_Casualties", "Number_of_Vehicles"], index = "Accident Date", aggfunc = max)

# %% [markdown]
# ## 9. PLOTING PIVOT CHART

# %%
# ploting the pivot table
pivot_table_df.style.background_gradient(cmap = "cubehelix")
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## 10. DISPLAYING CLEANED DATASET

# %%
# displaying first ten elements of the dataset
df.head(10)
# Out:
#   Accident_Index Accident Date Month  Year Day_of_Week  \
# 0  200901BS70001    2021-01-01   Jan  2021    Thursday
# 1  200901BS70002    2021-01-05   Jan  2021      Monday
# 2  200901BS70003    2021-01-04   Jan  2021      Sunday
# 3  200901BS70004    2021-01-05   Jan  2021      Monday
# 4  200901BS70005    2021-01-06   Jan  2021     Tuesday
# 5  200901BS70006    2021-01-01   Jan  2021    Thursday
# 6  200901BS70007    2021-01-08   Jan  2021    Thursday
# 7  200901BS70008    2021-01-02   Jan  2021      Friday
# 8  200901BS70009    2021-01-07   Jan  2021   Wednesday
# 9  200901BS70010    2021-01-10   Jan  2021    Saturday
#
#            Junction_Control          Junction_Detail Accident_Severity  \
# 0  Give way or uncontrolled  T or staggered junction           Serious
# 1  Give way or uncontrolled               Crossroads           Serious
# 2  Give way or uncontrolled  T or staggered junction            Slight
# 3       Auto traffic signal  T or staggered junction           Serious
# ...

# %% [markdown]
# ## 11. EXPORTING CLEANED DATASET FROM PYTHON TO EXCEL

# %%
# exporting dataset to my local machine for further analysis
df.to_excel(r"C:\Users\Dell\Desktop\3mtt_final_project_python_file.xlsx",  index=False)
